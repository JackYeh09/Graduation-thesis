# %%
#一個環境的數據結果
import pandas as pd

df = pd.read_csv("/workspace/pj/sumo-rl/outputs/n001/dqn_conn0_ep5.csv")
df
# Out:
#          step  system_total_stopped  system_total_waiting_time  \
# 0         0.0                     0                        0.0
# 1         5.0                     0                        0.0
# 2        10.0                    10                       10.0
# 3        15.0                     1                        1.0
# 4        20.0                     2                        2.0
# ...       ...                   ...                        ...
# 2876  14380.0                     8                       34.0
# 2877  14385.0                    11                       46.0
# 2878  14390.0                    12                       55.0
# 2879  14395.0                    10                       40.0
# 2880  14400.0                     6                       30.0
#
#       system_mean_waiting_time  system_mean_speed  system_total_queue  \
# 0                     0.000000           0.000000                   0
# ...

# %%
#第一個場景的流量
#每5秒生成多少台車
veh11hr = [6.926]*720
veh12hr = [9.084]*720
veh13hr = [7.970]*720
veh14hr = [7.863]*720

#每5秒生成多少個行人
ped11hr = [0.852]*720
ped12hr = [0.852]*720
ped13hr = [2.776]*720
ped14hr = [2.776]*720

#第二個場景的總流量
#每5秒生成多少台車
veh21hr = 
veh22hr = 
veh23hr = 
veh24hr = 

#每5秒生成多少個行人
ped11hr = 
ped12hr = 
ped13hr = 
ped14hr =

# %%
#所有車道的車總等待時間&車流量
import matplotlib.pyplot as plt
from matplotlib.spines import Spine

#左邊y軸
plt.plot(df.step, df['system_total_waiting_time'].rolling(20).mean(), color="r")
plt.ylabel("Total Waiting Time(s)")
plt.tick_params(axis='y')
plt.xlabel("Time Step(s)")

#右邊y軸_汽車流量
plt.twinx()
plt.plot(df.step, [0]+veh11hr+veh12hr+veh13hr+veh14hr, color="b", label = "Vehicle_Flows(per/5s)")
plt.ylabel("Flows")
plt.tick_params(axis='y', labelleft = False)

#右邊y軸_行人流量
plt.plot(df.step, [0]+ped11hr+ped12hr+ped13hr+ped14hr, color="orange", label = "Pedstrain_Flows(per/5s)")

plt.legend(bbox_to_anchor = (1.05, 1.0), loc = "upper left")

plt.plot()
# Out:
# []

# %%
#所有車道的車平均時速&車流量
#左邊y軸
plt.plot(df.step, df['system_mean_speed'].rolling(20).mean(), color="r")
plt.ylabel("Vehicle Mean Speed")
plt.tick_params(axis='y')
plt.xlabel("Time Step(s)")
plt.twinx()

#右邊y軸_汽車流量
plt.plot(df.step, [0]+veh11hr+veh12hr+veh13hr+veh14hr, color="b", label = "Vehicle_Flows(per/5s)")
plt.ylabel("Flows")
plt.tick_params(axis='y')

#右邊y軸_行人流量
plt.plot(df.step, [0]+ped11hr+ped12hr+ped13hr+ped14hr, color="orange", label = "Pedstrain_Flows(per/5s)")

plt.legend(bbox_to_anchor = (1.05, 1.0), loc = "upper left")

plt.plot()
# Out:
# []

# %%
#所有車道的擠了多少台車&車流量
#左邊y軸
plt.plot(df.step, df['system_total_queue'].rolling(20).mean(), color="r")
plt.ylabel("Total Queue")
plt.tick_params(axis='y')
plt.xlabel("Time Step(s)")
plt.twinx()

#右邊y軸_汽車流量
plt.plot(df.step, [0]+veh11hr+veh12hr+veh13hr+veh14hr, color="b", label = "Vehicle_Flows(per/5s)")
plt.ylabel("Flows")
plt.tick_params(axis='y')

#右邊y軸_行人流量
plt.plot(df.step, [0]+ped11hr+ped12hr+ped13hr+ped14hr, color="orange", label = "Pedstrain_Flows(per/5s)")

plt.legend(bbox_to_anchor = (1.05, 1.0), loc = "upper left")

plt.plot()
# Out:
# []

# %%
#兩個環境下的數據結果
df2 = pd.read_csv("/workspace/pj/sumo-rl/outputs/n002/dqn_conn0_ep5.csv")
df2
# Out:
#          step  system_total_stopped  system_total_waiting_time  \
# 0         0.0                     0                        0.0
# 1         5.0                     0                        0.0
# 2        10.0                    10                       20.0
# 3        15.0                     0                        0.0
# 4        20.0                     2                        2.0
# ...       ...                   ...                        ...
# 2876  14380.0                    13                       60.0
# 2877  14385.0                     4                        8.0
# 2878  14390.0                     9                       38.0
# 2879  14395.0                    15                       99.0
# 2880  14400.0                    20                      137.0
#
#       system_mean_waiting_time  system_mean_speed  system_total_queue  \
# 0                     0.000000           0.000000                   0
# ...

# %%
#所有車道的車總等待時間&車流量
#左邊y軸
plt.plot(df2.step, df2['system_total_waiting_time'].rolling(20).mean(), color="r")
plt.ylabel("Total Waiting Time(s)")
plt.tick_params(axis='y')
plt.xlabel("Time Step(s)")
plt.twinx()

#右邊y軸_汽車流量
plt.plot(df2.step, [0]+veh11hr+veh12hr+veh13hr+veh14hr, color="b", label = "Vehicle_Flows(per/5s)")
plt.ylabel("Flows")
plt.tick_params(axis='y')

#右邊y軸_行人流量
plt.plot(df.step, [0]+ped11hr+ped12hr+ped13hr+ped14hr, color="orange", label = "Pedstrain_Flows(per/5s)")

plt.legend(bbox_to_anchor = (1.05, 1.0), loc = "upper left")

plt.plot()
# Out:
# []

# %%
#所有車道的車平均時速&車流量
#左邊y軸
plt.plot(df2.step, df2['system_mean_speed'].rolling(20).mean(), color="r")
plt.ylabel("Vehicle Mean Speed")
plt.tick_params(axis='y')
plt.xlabel("Time Step(s)")
plt.twinx()

#右邊y軸_汽車流量
plt.plot(df2.step, [0]+veh11hr+veh12hr+veh13hr+veh14hr, color="b", label = "Vehicle_Flows(per/5s)")
plt.ylabel("Flows")
plt.tick_params(axis='y')

#右邊y軸_行人流量
plt.plot(df.step, [0]+ped11hr+ped12hr+ped13hr+ped14hr, color="orange", label = "Pedstrain_Flows(per/5s)")

plt.legend(bbox_to_anchor = (1.05, 1.0), loc = "upper left")

plt.plot()
# Out:
# []

# %%
#所有車道的擠了多少台車&車流量
#左邊y軸
plt.plot(df2.step, df2['system_total_queue'].rolling(20).mean(), color="r")
plt.ylabel("Total Lane Queue")
plt.tick_params(axis='y')
plt.xlabel("Time Step(s)")
plt.twinx()

#右邊y軸_汽車流量
plt.plot(df2.step, [0]+veh11hr+veh12hr+veh13hr+veh14hr, color="b", label = "Vehicle_Flows(per/5s)")
plt.ylabel("Flows")
plt.tick_params(axis='y')

#右邊y軸_行人流量
plt.plot(df.step, [0]+ped11hr+ped12hr+ped13hr+ped14hr, color="orange", label = "Pedstrain_Flows(per/5s)")

plt.legend(bbox_to_anchor = (1.05, 1.0), loc = "upper left")

plt.plot()
# Out:
# []
